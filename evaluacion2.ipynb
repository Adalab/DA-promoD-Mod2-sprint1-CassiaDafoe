# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as st
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Evaluacion 3: Cassia Dafoe
#
# ## NumPy
#
# 1. Importa la librería de NumPy.
# 2. Crea un array de 1 dimension y 10 elementos.

# %%
array1 = np.random.randint(0,100,(10))
array1
# Out:
# array([86, 73, 74, 97, 99, 11,  6, 48,  5,  4])

# %% [markdown]
# 3. Reemplaza todos los números impares por el valor "par" y los pares por "par". Para hacer esto os tendréis que crear un array nuevo donde vayáis añadiendo los valores nuevos.

# %%
# para crear un array con valores de tipo strings, creo un array "vacio" de tipo "list" 
# de tipo "string" solo me cogia la primera letra de las palabras par o impar
array2 = np.empty((10), dtype = list)
array2
# Out:
# array([None, None, None, None, None, None, None, None, None, None],
#       dtype=object)

# %%
# con un for loop podemos iterar por el array original y reemplazar los valores segun si se
# pueden dividir por 2 sin resto o no (si son par o no); y segun el resultados reemplazamos
# el valor en la misma posicion del array1 por la palabra apropriada
for i, valor in enumerate(array1):
    if valor % 2 ==0:
        array2[i] = "par"
    else:
        array2[i] = "impar"

# %%
array2
# Out:
# array(['par', 'impar', 'par', 'impar', 'impar', 'impar', 'par', 'par',
#        'impar', 'par'], dtype=object)

# %% [markdown]
# 4. Cambiad la forma del array del ejercicio 3 a un array de 2 filas y 5 columnas.

# %%
array2 = np.reshape(array2,(2,5))
array2
# Out:
# array([['par', 'impar', 'par', 'impar', 'impar'],
#        ['impar', 'par', 'par', 'impar', 'par']], dtype=object)

# %% [markdown]
# 5. Extrae los elementos comunes de los siguientes arrays

# %%
array1a = np.array([1,2,3,2,3,4,3,4,5,6])
array2a = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
np.intersect1d(array1a, array2a)
# Out:
# array([2, 4])

# %% [markdown]
# 6. Extraed los elementos que están en el array1 pero no en el array2.

# %%
np.setdiff1d(array1a, array2a)
# Out:
# array([1, 3, 5, 6])

# %% [markdown]
# 7. Extraed las posiciones donde tengamos elementos que sean iguales.

# %%
# iteramos por los arrays y los valores que tienen iguales para sacar los indices con np.where
for array in [array1a, array2a]:
    for i in np.intersect1d(array1a, array2a):
        print(f"Los indices del elemento igual {i} son {np.where(array == i)}")
# Out:
# Los indices del elemento igual 2 son (array([1, 3]),)
# Los indices del elemento igual 4 son (array([5, 7]),)
# Los indices del elemento igual 2 son (array([1, 3]),)
# Los indices del elemento igual 4 son (array([5, 7]),)

# %% [markdown]
# 8. Cread un array de 3 filas y 5 columnas, con números enteros del 0 al 50. Una vez creado, extrae los valores que sean menores que 10 y mayores que 40.

# %%
array4 = np.random.randint(0, 50, (3,5))
array4
# Out:
# array([[44, 12, 38, 12, 43],
#        [36,  7, 37, 35,  1],
#        [22,  3, 16, 36, 43]])

# %%
array[(array < 10) | (array > 40)]
# Out:
# array([7, 2, 2, 7, 4, 9, 4, 9, 8])

# %% [markdown]
# 9. Cread un array de 5x3 con números decimales aleatorios entre el 5 y el 10.

# %%
array5 = np.random.randint(5, 9, (5,3)) + np.random.random_sample((5,3))

array5
# Out:
# array([[8.8256391 , 5.21111635, 5.01804408],
#        [5.62701912, 7.68657166, 5.39647265],
#        [6.37017841, 5.45100899, 6.57119966],
#        [5.97504026, 7.168294  , 7.85560909],
#        [8.57253324, 8.14938292, 8.92681966]])

# %% [markdown]
# 10. Crea un array de tres dimensiones de 2x4x7 con números entre el 1 y el 20
# - Transponed el array para que tenga 4 matrices, 7 filas y 2 columnas

# %%
array6 = np.random.randint(1, 20, (2,4,7))
array6
# Out:
# array([[[ 9,  8, 19,  9,  9,  7,  6],
#         [ 5,  1,  1,  2,  6, 12,  3],
#         [16, 13,  5,  7,  1,  2, 17],
#         [ 9,  1,  7,  3, 17,  2, 19]],
#
#        [[18,  8, 11,  3, 10, 12,  3],
#         [ 5, 16, 14,  9, 11, 15,  2],
#         [19,  6, 16,  5, 11,  9, 19],
#         [12, 13,  8,  5,  3, 14,  5]]])

# %%
array6 = np.reshape(array6, (4,7,2))
array6
# Out:
# array([[[ 9,  8],
#         [19,  9],
#         [ 9,  7],
#         [ 6,  5],
#         [ 1,  1],
#         [ 2,  6],
#         [12,  3]],
#
#        [[16, 13],
#         [ 5,  7],
#         [ 1,  2],
#         [17,  9],
#         [ 1,  7],
#         [ 3, 17],
#         [ 2, 19]],
#
#        [[18,  8],
#         [11,  3],
#         [10, 12],
#         [ 3,  5],
#         [16, 14],
#         [ 9, 11],
#         [15,  2]],
#
#        [[19,  6],
#         [16,  5],
#         [11,  9],
#         [19, 12],
#         [13,  8],
#         [ 5,  3],
#         [14,  5]]])

# %% [markdown]
# ## Ejercicios de Pandas

# %%
pd.options.display.max_columns=None

# %%
df = pd.read_csv('datos/Spotify_Youtube.csv', index_col=0)

# %%
def exploracion(dataframe, nombre):
    print(f"Exploracion del dataframe '{nombre}'")
    print(".............................................")
    print(f"Las primeras 5 filas:")
    display(dataframe.head())
    print(".............................................")
    print(f"Las últimas 5 filas:")
    display(dataframe.head())
    print(".............................................")
    print(f"5 filas aleatorias:")
    display(dataframe.sample(5))
    print(".............................................")
    print(f"En el dataframe hay {dataframe.shape[0]} filas y {dataframe.shape[1]} columnas.")
    print(".............................................")
    print(f"Los tipos de data por columna del dataframe son:")
    display(df.dtypes.reset_index())
    print(".............................................")
    print(f"La cantidad de nulos por columna del dataframe son:")
    display(df.isnull().sum().reset_index())
    print(".............................................")
    if dataframe.duplicated().sum() != 0:
        print(f"En el dataframe hay {dataframe.duplicated().sum()} filas duplicadas.")
    else:
        print(f"No hay filas duplicadas.")
    print(".............................................")
    print(f"Los principales estadísticos de las columnas numéricas son:")
    display(dataframe.describe())
    print(".............................................")
    print(f"Los principales estadísticos de las columnas categóricas son:")
    display(dataframe.describe(include=object))
    print(".............................................")

# %%
exploracion(df, "Spotify and Youtube Song Data")
# Out:
# Exploracion del dataframe 'Spotify and Youtube Song Data'
# .............................................
# Las primeras 5 filas:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            album album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08
# .............................................
# Las últimas 5 filas:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            album album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08
# .............................................
# 5 filas aleatorias:
#                                    artist  \
# 18583                                Joji
# 7103                        Gloria Gaynor
# 7862                      Ying Yang Twins
# 7712                      Sarah McLachlan
# 6988   Ramon Ayala Y Sus Bravos Del Norte
#
#                                              url_spotify  \
# 18583  https://open.spotify.com/artist/3MZsBdqDrRTJih...
# 7103   https://open.spotify.com/artist/6V6WCgi7waF55b...
# 7862   https://open.spotify.com/artist/44PA0rCQXikgOW...
# 7712   https://open.spotify.com/artist/4NgNsOXSwIzXlU...
# 6988   https://open.spotify.com/artist/5j9R5dTGerKvdX...
#
#                                     track                              album  \
# 18583                Feeling Like The End                        SMITHEREENS
# 7103   I Will Survive - 1981 Re-recording                     I Will Survive
# 7862                     What's Happenin!                    Me & My Brother
# 7712                                 Adia                          Surfacing
# 6988                    Un Puño De Tierra  Un Puño De Tierra (Remasterizado)
#
#       album_type                                   uri  danceability  energy  \
# 18583      album  spotify:track:1abwytAhbWeHrbsA9eODOy         0.794   0.668
# 7103       album  spotify:track:7DD1ojeTUwnW65g5QuZw7X         0.668   0.678
# 7862       album  spotify:track:5Sw4NiI7SniktcUwPweTvs         0.829   0.684
# 7712       album  spotify:track:0rl84FuazRHYmK72krdmA1         0.526   0.370
# 6988       album  spotify:track:68wJxErG62CG0R5tBgCcia         0.539   0.717
#
#        key  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 18583  2.0    -7.689       0.0646       0.29900          0.001040    0.0899
# 7103   9.0   -10.317       0.0560       0.00293          0.000000    0.2650
# 7862   6.0    -6.473       0.0606       0.10200          0.000000    0.3480
# 7712   3.0   -10.535       0.0250       0.72200          0.000000    0.1570
# 6988   9.0    -6.819       0.1960       0.10300          0.000036    0.0710
#
#        valence    tempo  duration_ms  \
# 18583    0.632  148.016     102480.0
# 7103     0.657  120.029     261173.0
# 7862     0.731  107.985     259733.0
# 7712     0.251   76.002     244667.0
# 6988     0.870  208.029     226360.0
#
#                                        url_youtube  \
# 18583  https://www.youtube.com/watch?v=-1mgA2wKQF8
# 7103   https://www.youtube.com/watch?v=6dYWe1c3OyU
# 7862   https://www.youtube.com/watch?v=Td4XmEh7Ya0
# 7712   https://www.youtube.com/watch?v=Q5wW8N4pt3U
# 6988   https://www.youtube.com/watch?v=WGFl9O-0hMY
#
#                                                    title  \
# 18583                        Joji - Feeling Like The End
# 7103   Gloria Gaynor - I Will Survive (Official Music...
# 7862   Ying Yang Twins - What's Happenin' (feat. Tric...
# 7712                              Sarah McLachlan - Adia
# 6988   RAMON AYALA Y LOS BRAVOS DEL NORTE    ' Un Puñ...
#
#                      channel       views     likes  comments  \
# 18583                   Joji   2147515.0   95125.0    3001.0
# 7103        GloriaGaynorVEVO  19480336.0  290573.0    4441.0
# 7862   Radial by The Orchard   9539008.0   56648.0    1805.0
# 7712      sarahmclachlanVEVO   7023713.0   44374.0    2581.0
# 6988                 J.R C.L     16194.0      48.0       0.0
#
#                                              description licensed  \
# 18583  Stream 'SMITHEREENS': https://joji.lnk.to/SMIT...     True
# 7103   Gloria Gaynor's official music video for "I Wi...     True
# 7862   Official music video for Ying Yang Twins - Wha...     True
# 7712   Sarah McLachlan's official music video for 'Ad...     True
# 6988                  Ramon Ayala Y Los Bravos del norte    False
#
#       official_video       stream
# 18583           True   33899806.0
# 7103            True  119771464.0
# 7862            True   13446125.0
# 7712            True   31376985.0
# 6988           False   19852695.0
# .............................................
# En el dataframe hay 20718 filas y 27 columnas.
# .............................................
# Los tipos de data por columna del dataframe son:
#                index        0
# 0             artist   object
# 1        url_spotify   object
# 2              track   object
# 3              album   object
# 4         album_type   object
# 5                uri   object
# 6       danceability  float64
# 7             energy  float64
# 8                key  float64
# 9           loudness  float64
# 10       speechiness  float64
# 11      acousticness  float64
# 12  instrumentalness  float64
# 13          liveness  float64
# 14           valence  float64
# 15             tempo  float64
# 16       duration_ms  float64
# 17       url_youtube   object
# 18             title   object
# 19           channel   object
# 20             views  float64
# 21             likes  float64
# 22          comments  float64
# 23       description   object
# 24          licensed   object
# 25    official_video   object
# 26            stream  float64
# .............................................
# La cantidad de nulos por columna del dataframe son:
#                index    0
# 0             artist    0
# 1        url_spotify    0
# 2              track    0
# 3              album    0
# 4         album_type    0
# 5                uri    0
# 6       danceability    2
# 7             energy    2
# 8                key    2
# 9           loudness    2
# 10       speechiness    2
# 11      acousticness    2
# 12  instrumentalness    2
# 13          liveness    2
# 14           valence    2
# 15             tempo    2
# 16       duration_ms    2
# 17       url_youtube  470
# 18             title  470
# 19           channel  470
# 20             views  470
# 21             likes  541
# 22          comments  569
# 23       description  876
# 24          licensed  470
# 25    official_video  470
# 26            stream  576
# .............................................
# No hay filas duplicadas.
# .............................................
# Los principales estadísticos de las columnas numéricas son:
#        danceability        energy           key      loudness   speechiness  \
# count  20716.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean       0.619777      0.635250      5.300348     -7.671680      0.096456
# std        0.165272      0.214147      3.576449      4.632749      0.111960
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518000      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740250      0.798000      8.000000     -4.931000      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        acousticness  instrumentalness      liveness       valence  \
# count  20716.000000      20716.000000  20716.000000  20716.000000
# mean       0.291535          0.055962      0.193521      0.529853
# std        0.286299          0.193262      0.168531      0.245441
# min        0.000001          0.000000      0.014500      0.000000
# 25%        0.045200          0.000000      0.094100      0.339000
# 50%        0.193000          0.000002      0.125000      0.537000
# 75%        0.477250          0.000463      0.237000      0.726250
# max        0.996000          1.000000      1.000000      0.993000
#
#               tempo   duration_ms         views         likes      comments  \
# count  20716.000000  2.071600e+04  2.024800e+04  2.017700e+04  2.014900e+04
# mean     120.638340  2.247176e+05  9.393782e+07  6.633411e+05  2.751899e+04
# std       29.579018  1.247905e+05  2.746443e+08  1.789324e+06  1.932347e+05
# min        0.000000  3.098500e+04  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       97.002000  1.800095e+05  1.826002e+06  2.158100e+04  5.090000e+02
# 50%      119.965000  2.132845e+05  1.450110e+07  1.244810e+05  3.277000e+03
# 75%      139.935000  2.524430e+05  7.039975e+07  5.221480e+05  1.436000e+04
# max      243.372000  4.676058e+06  8.079649e+09  5.078865e+07  1.608314e+07
#
#              stream
# count  2.014200e+04
# mean   1.359422e+08
# std    2.441321e+08
# min    6.574000e+03
# 25%    1.767486e+07
# 50%    4.968298e+07
# 75%    1.383581e+08
# max    3.386520e+09
# .............................................
# Los principales estadísticos de las columnas categóricas son:
#           artist                                        url_spotify  \
# count      20718                                              20718
# unique      2079                                               2079
# top     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# freq          10                                                 10
#
#                                             track          album album_type  \
# count                                       20718          20718      20718
# unique                                      17841          11933          3
# top     El Ultimo Adiós - Varios Artistas Version  Greatest Hits      album
# freq                                           24             30      14926
#
#                                          uri  \
# count                                  20718
# unique                                 18862
# top     spotify:track:0tzixmHNQfE6S6SirSToxW
# freq                                      24
#
#                                         url_youtube  \
# count                                         20248
# unique                                        18154
# top     https://www.youtube.com/watch?v=GqOvxbFLwjY
# freq                                             18
#
#                                                     title   channel  \
# count                                               20248     20248
# unique                                              18146      6714
# top     Color Esperanza 2020 - Various Artists (Offici...  T-Series
# freq                                                   18       238
#
#        description licensed official_video
# count        19842    20248          20248
# unique       17395        2              2
# top                    True           True
# freq           114    14140          15723
# .............................................

# %% [markdown]
# 3. Preparación de los datos:
#
# - Los nombres de las columnas empiezan con mayúsculas, poned todos los nombres de las columnas en minúsculas.

# %%
diccionario = {col : col.lower() for col in df.columns}

df.rename(columns = diccionario, inplace = True)

df.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %% [markdown]
# - Haciendo el análisis exploratorio nos deberíamos haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Cread una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.

# %%
def tipo_float(columna):
    try:
        columna = columna.replace(",", ".")
        return float(columna)
    except:
        return columna

# %%
def columna_float(dataframe):
    for column in dataframe:
        dataframe[column] = dataframe[column].apply(tipo_float)
    display(dataframe.dtypes.reset_index())

# %%
columna_float(df)
# Out:
#                index        0
# 0             artist   object
# 1        url_spotify   object
# 2              track   object
# 3              album   object
# 4         album_type   object
# 5                uri   object
# 6       danceability  float64
# 7             energy  float64
# 8                key  float64
# 9           loudness  float64
# 10       speechiness  float64
# 11      acousticness  float64
# 12  instrumentalness  float64
# 13          liveness  float64
# 14           valence  float64
# 15             tempo  float64
# 16       duration_ms  float64
# 17       url_youtube   object
# 18             title   object
# 19           channel   object
# 20             views  float64
# 21             likes  float64
# 22          comments  float64
# 23       description   object
# 24          licensed   object
# 25    official_video   object
# 26            stream  float64

# %% [markdown]
# - Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haced lo mismo para las columnas de "track" y "album".

# %%
def lower(columna):
    try:
        return columna.lower()
    except:
        return columna

# %%
def columna_lower(dataframe, *columnas):
    for col in columnas:
        dataframe[col] = dataframe[col].apply(lower)
    display(dataframe.head(3))

# %%
columna_lower(df, *['track', 'album'])
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 feel good inc.
# 1                                rhinestone eyes
# 2  new gold (feat. tame impala and bootie brown)
#
#                                            album album_type  \
# 0                                     demon days      album
# 1                                  plastic beach      album
# 2  new gold (feat. tame impala and bootie brown)     single
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0    -3.930
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
# 2       0.0522       0.04250          0.046900    0.1160    0.551  108.014
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07

# %% [markdown]
# - Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Cread una función que nos elimine este símbolo de los nombres de los artistas.

# %%
# vemos unos ejemplos de artistas con un $ en el nombre
df_dollar = df[df['artist'].astype(str).str.contains("\$", regex=True, na=False)]
df_dollar.head(5)
# Out:
#          artist                                        url_spotify  \
# 5332  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5333  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5334  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5335  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5336  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
#
#                                                   track  \
# 5332                                   blow the whistle
# 5333           gettin' it (feat. parliament funkadelic)
# 5334  big subwoofer (feat. snoop dogg. ice cube. e-4...
# 5335                      i'm a player - street version
# 5336                                         the ghetto
#
#                               album album_type  \
# 5332               blow the whistle      album
# 5333  gettin' it (album number ten)      album
# 5334                  big subwoofer     single
# 5335        get in where you fit in      album
# 5336       short dog's in the house      album
#
#                                        uri  danceability  energy   key  \
# 5332  spotify:track:2lMg3lCMOGistaWBNGjuT3         0.907   0.625   1.0
# 5333  spotify:track:5K5dQsYdSdo2LKdepxbYAd         0.902   0.410   1.0
# 5334  spotify:track:5GPm7PsMQwceQvfYlGXcCt         0.920   0.549  11.0
# 5335  spotify:track:4XiZFtOlgXYtrp88tGNnk8         0.880   0.558   9.0
# 5336  spotify:track:3B6WDceNe6lUQnczntRIuf         0.947   0.354   6.0
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 5332    -5.557        0.198        0.0042          0.000000     0.151
# 5333    -5.310        0.219        0.1760          0.000000     0.119
# 5334    -5.912        0.257        0.0262          0.000003     0.196
# 5335   -10.426        0.217        0.1210          0.000034     0.119
# 5336   -12.844        0.270        0.0455          0.000057     0.212
#
#       valence    tempo  duration_ms  \
# 5332    0.605   99.918     163133.0
# 5333    0.647   84.070     341427.0
# 5334    0.709   90.004     241587.0
# 5335    0.597   89.024     361267.0
# 5336    0.360  100.087     302133.0
#
#                                       url_youtube  \
# 5332  https://www.youtube.com/watch?v=CBJtzEKetBM
# 5333  https://www.youtube.com/watch?v=8wDziTMsA9k
# 5334  https://www.youtube.com/watch?v=tqiXwx0NG0Q
# 5335  https://www.youtube.com/watch?v=WJg6KYPtu28
# 5336  https://www.youtube.com/watch?v=fw0uz88E2gI
#
#                                                   title              channel  \
# 5332   TOO SHORT - Blow The Whistle (Official HD Video)         TooShortVEVO
# 5333  Too $hort - Gettin' It (Official Video) ft. Pa...         TooShortVEVO
# 5334  MOUNT WESTMORE – Big Subwoofer (Official Music...          SnoopDoggTV
# 5335                        I’m a Player-Street version  LEGO technic BIGBRO
# 5336                             Too $hort - The Ghetto         TooShortVEVO
#
#            views     likes  comments  \
# 5332  55688289.0  369856.0    9781.0
# 5333   3477753.0   60777.0     737.0
# 5334  29491847.0  485400.0   18232.0
# 5335      4913.0     102.0      16.0
# 5336  33688920.0  314303.0    8338.0
#
#                                             description licensed  \
# 5332  Official HD video for “Blow The Whistle” by To...     True
# 5333  Official Video for "Gettin' It" by Too $hort\n...     True
# 5334  Stream/Download “Big Subwoofer”: https://Snoop...    False
# 5335                                                NaN    False
# 5336  Too $hort's official music video for 'The Ghet...     True
#
#      official_video      stream
# 5332           True  72987947.0
# 5333           True  58456976.0
# 5334          False  17541227.0
# 5335          False  31270170.0
# 5336           True  27122600.0

# %%
# creo una funcion para sustituir los $ por strings vacios
def dollar(columna):
    try:
        patron = "\$"
        return re.sub(patron, "", columna)
    except:
        return columna

# %%
# aplico la funcion a la columna "artist"
df['artist'] = df['artist'].apply(dollar)

# %%
# compruebo que ya no hay artistas con $
df_dollar2 = df[df['artist'].astype(str).str.contains("\$", regex=True, na=False)]
df_dollar2.head(5)
# Out:
# Empty DataFrame
# Columns: [artist, url_spotify, track, album, album_type, uri, danceability, energy, key, loudness, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, url_youtube, title, channel, views, likes, comments, description, licensed, official_video, stream]
# Index: []

# %% [markdown]
# 4. Filtrado de datos y Visualización:
#
# - ¿Cuáles son los valores únicos de la columna "album_type"? Cread tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
df['album_type'].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
df_album = df[df['album_type'] == 'album']

display(df_album.head(2))

print(f"Hay {df_album.shape[0]} canciones en la categoria de album type 'album'")
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   feel good inc.     demon days      album
# 1  rhinestone eyes  plastic beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# Hay 14926 canciones en la categoria de album type 'album'

# %%
df_single = df[df['album_type'] == 'single']

display(df_single.head(2))

print(f"Hay {df_single.shape[0]} canciones en la categoria de album type 'single'")
# Out:
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                track  \
# 2      new gold (feat. tame impala and bootie brown)
# 6  new gold (feat. tame impala and bootie brown) ...
#
#                                                album album_type  \
# 2      new gold (feat. tame impala and bootie brown)     single
# 6  new gold (feat. tame impala and bootie brown) ...     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0    -3.930
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897  4.0    -7.185
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
# 6       0.0629        0.0120            0.2620     0.325    0.358  127.030
#
#    duration_ms                                  url_youtube  \
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 6     274142.0  https://www.youtube.com/watch?v=BONNm0F7Tto
#
#                                                title    channel      views  \
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...   Gorillaz  8435055.0
# 6  Gorillaz - New Gold ft. Tame Impala. Bootie Br...  Dom Dolla   451996.0
#
#       likes  comments                                        description  \
# 2  282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 6   11686.0     241.0  Gorillaz 'New Gold' ft. Tame Impala. Bootie Br...
#
#   licensed official_video      stream
# 2     True           True  63063467.0
# 6    False           True  10666154.0
# Hay 5004 canciones en la categoria de album type 'single'

# %%
df_compilation = df[df['album_type'] == 'compilation']

display(df_compilation.head(2))

print(f"Hay {df_compilation.shape[0]} canciones en la categoria de album type 'compilation'")
# Out:
#         artist                                        url_spotify  \
# 154    Shakira  https://open.spotify.com/artist/0EmeFodog0BfCg...
# 206  Sean Paul  https://open.spotify.com/artist/3Isy6kedDrgPYo...
#
#                                                  track  \
# 154  waka waka (this time for africa) [the official...
# 206  (when you gonna) give it up to me (feat. keysh...
#
#                                                  album   album_type  \
# 154  listen up! the official 2010 fifa world cup album  compilation
# 206                                          only hits  compilation
#
#                                       uri  danceability  energy  key  \
# 154  spotify:track:6bNB5gxFX6Q87DbQWb8OWZ         0.758   0.871  2.0
# 206  spotify:track:6k8uthjEbttfWXcGaNTQGD         0.711   0.761  8.0
#
#      loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 154    -6.408        0.147        0.0062               0.0    0.0663    0.753
# 206    -3.040        0.225        0.0670               0.0    0.0410    0.718
#
#        tempo  duration_ms                                  url_youtube  \
# 154  126.994     202627.0  https://www.youtube.com/watch?v=pRpeEdMmmQ0
# 206   95.824     243880.0  https://www.youtube.com/watch?v=bMoNV9oWs2E
#
#                                                  title           channel  \
# 154  Shakira - Waka Waka (This Time for Africa) (Th...       shakiraVEVO
# 206  Sean Paul - Give It Up To Me (feat. Keyshia Co...  Atlantic Records
#
#             views       likes   comments  \
# 154  3.463816e+09  20327883.0  1283529.0
# 206  3.068871e+08   1317175.0    17399.0
#
#                                            description licensed  \
# 154  Watch the official music video for "Waka Waka ...     True
# 206  The official video of "Give It Up To Me (feat....     True
#
#     official_video       stream
# 154           True  629918488.0
# 206           True   51339097.0
# Hay 788 canciones en la categoria de album type 'compilation'

# %% [markdown]
# - Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Mostrad los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordenar los resultados de mayor a menor en base a la media.

# %%
df_danceability = df.groupby('artist', dropna=True)['danceability'].agg(['mean', 'std'])
df_danceability.sort_values('mean', ascending=False)
# Out:
#                             mean       std
# artist
# Saweetie                0.885800  0.050918
# Young Dolph             0.862900  0.046596
# Megan Thee Stallion     0.860500  0.091036
# Dave                    0.859100  0.096773
# Ovy On The Drums        0.854600  0.038739
# ...                          ...       ...
# Stephen Cleobury        0.142160  0.039799
# Ocean Sounds            0.137980  0.063706
# Ocean Waves For Sleep   0.128150  0.060672
# White Noise for Babies  0.080233  0.156234
# White Noise Baby Sleep  0.066270  0.071434
#
# [2079 rows x 2 columns]

# %%
df_acousticness = df.groupby('artist', dropna=True)['acousticness'].agg(['mean', 'std'])
df_acousticness.sort_values('mean', ascending=False)
# Out:
#                          mean       std
# artist
# Claude Debussy       0.993600  0.001350
# Robert Schumann      0.992500  0.005503
# Frédéric Chopin      0.990200  0.003795
# Edvard Grieg         0.989500  0.007863
# Lang Lang            0.989100  0.004677
# ...                       ...       ...
# Youjeen              0.000334  0.000654
# Volbeat              0.000220  0.000237
# Motionless In White  0.000166  0.000191
# Killswitch Engage    0.000132  0.000158
# In Flames            0.000050  0.000099
#
# [2079 rows x 2 columns]

# %%
df_speechiness = df.groupby('artist', dropna=True)['speechiness'].agg(['mean', 'std'])
df_speechiness.sort_values('mean', ascending=False)
# Out:
#                            mean       std
# artist
# Sir Arthur Conan Doyle  0.95230  0.008845
# Bibi Blocksberg         0.94530  0.011879
# Sherlock Holmes         0.93930  0.015833
# TKKG                    0.91930  0.023542
# Fünf Freunde            0.90620  0.048960
# ...                         ...       ...
# Marcela Gandara         0.02861  0.002700
# Los Temerarios          0.02841  0.005328
# Jeet Gannguli           0.02822  0.003086
# Los Acosta              0.02764  0.002200
# Cigarettes After Sex    0.02741  0.002586
#
# [2079 rows x 2 columns]

# %% [markdown]
# - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, querremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#     - Agrupar por artista y calcular la media de visitas y de likes.
#     - Quedaros con los 10 artistas que más visitas han tenido.
#     - Quedaros con los 10 artistas que más likes han tenido.
#     - Haced un subplot, donde en uno tengamos los 10 artistas con más likes y en el otro los 10 artistas con mas views.
#     - BONUS Haced lo mismo para los datos de tipo "single".
